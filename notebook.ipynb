# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** Celvin Fahryan Dwi Zatmiko
# - **Email:** mc006d5y1376@student.devacademy.id
# - **ID Dicoding:** mc006d5y1376

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana tren pengguna baru dengan pengguna casual dalam beberapa tahun terakhir?
# - Bagaimana pola penyewaan dari pagi hingga malam hari?
# - Bagaimana persebaran penyewaan pada setiap musim?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
day_df = pd.read_csv('/content/drive/MyDrive/Dataset/bike-sharing/day.csv')
day_df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
hour_df = pd.read_csv('/content/drive/MyDrive/Dataset/bike-sharing/hour.csv')
hour_df
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Day

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
print(day_df.duplicated().sum())
day_df.isnull().sum()
# Out:
# 0
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# #### Hour

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
print(hour_df.duplicated().sum())
hour_df.isnull().sum()
# Out:
# 0
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# **Insight:**
# - xxx
# - xxx

# %% [markdown]
# ### Cleaning Data

# %%
# Mengganti nama kolom agar lebih mudah dibaca
day_df.rename(columns={
    'dteday': 'dateday',
    'yr':'year',
    'mnth':'month',
    'hr': 'hour',
    'weathersit':'weather',
    'windspeed':'wind_speed',
    'cnt':'count_cr',
    'hum':'humidity'},inplace=True)

hour_df.rename(columns={
    'dteday': 'dateday',
    'yr':'year',
    'mnth':'month',
    'hr': 'hour',
    'weathersit':'weather',
    'windspeed':'wind_speed',
    'cnt':'count_cr',
    'hum':'humidity'},inplace=True)

# %%
# Ubah tipe data
day_df['dateday'] = pd.to_datetime(day_df['dateday'])
hour_df['dateday'] = pd.to_datetime(hour_df['dateday'])

day_df.info()
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dateday     731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   year        731 non-null    int64
#  4   month       731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weather     731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  humidity    731 non-null    float64
#  12  wind_speed  731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  count_cr    731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
# membuat tabel baru bernama category days untuk mencari tau weekend or weekdays
day_df['category_days'] = day_df['weekday'].apply(lambda x: 'Weekend' if x in [0, 6] else 'Weekday')
hour_df['category_days'] = hour_df['weekday'].apply(lambda x: 'Weekend' if x in [0, 6] else 'Weekday')

# %% [markdown]
# **Insight:**
# - mengganti nama kolom agar lebih mudah dibaca ✓
# - mengubah tipe data pada kolom dteday menjadi datetime ✓
# - membuat kolom baru bernama category_days yang berisi weekend atau weekdays ✓

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore data Day

# %%
day_df.describe(include='all')
# Out:
#            instant              dateday      season        year       month  \
# count   731.000000                  731  731.000000  731.000000  731.000000
# unique         NaN                  NaN         NaN         NaN         NaN
# top            NaN                  NaN         NaN         NaN         NaN
# freq           NaN                  NaN         NaN         NaN         NaN
# mean    366.000000  2012-01-01 00:00:00    2.496580    0.500684    6.519836
# min       1.000000  2011-01-01 00:00:00    1.000000    0.000000    1.000000
# 25%     183.500000  2011-07-02 12:00:00    2.000000    0.000000    4.000000
# 50%     366.000000  2012-01-01 00:00:00    3.000000    1.000000    7.000000
# 75%     548.500000  2012-07-01 12:00:00    3.000000    1.000000   10.000000
# max     731.000000  2012-12-31 00:00:00    4.000000    1.000000   12.000000
# std     211.165812                  NaN    1.110807    0.500342    3.451913
#
# ...

# %% [markdown]
# **Insight:**
# Berdasarkan rangkuman parameter statistik di atas, kita akan memperoleh informasi jumlah pelanggan sebanyak 731.

# %%
# penyewaan berdasarkan hari
hour_df.groupby(by="weekday").agg({
    "count_cr": ["sum"]
})
# Out:
#         count_cr
#              sum
# weekday
# 0         444027
# 1         455503
# 2         469109
# 3         473048
# 4         485395
# 5         487790
# 6         477807

# %% [markdown]
# Berdasarkan hasil diatas, jumlah penyewaan tertinggi terjadi pada hari Jumat dan terendah pada hari minggu

# %%
fig, axe = plt.subplots(figsize=(15,5))
correlation_matrix = day_df.corr(numeric_only=True)
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
sns.heatmap(correlation_matrix, annot=True, mask=mask, cmap="coolwarm", center=0, fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Berdasarkana matrix tersebut, kita mendapat beberapa informasi, yaitu
# 1. Korelasi positif kuat
# - temp dengan atemp
# - count_cr dengan registered
# - instant dengan year
# - season dengan month
# 2. Fitur yang memiliki korelasi kuat dengan total penyewaan sepeda, baik untuk penyewaan harian maupun pengguna terdaftar ("count_cr"), antara lain:
# - registered
# - casual
# - atemp
# - temp
# - instant

# %% [markdown]
# ### Explore data Hour

# %%
hour_df.describe(include='all')
# Out:
#            instant                        dateday        season          year  \
# count   17379.0000                          17379  17379.000000  17379.000000
# unique         NaN                            NaN           NaN           NaN
# top            NaN                            NaN           NaN           NaN
# freq           NaN                            NaN           NaN           NaN
# mean     8690.0000  2012-01-02 04:08:34.552045568      2.501640      0.502561
# min         1.0000            2011-01-01 00:00:00      1.000000      0.000000
# 25%      4345.5000            2011-07-04 00:00:00      2.000000      0.000000
# 50%      8690.0000            2012-01-02 00:00:00      3.000000      1.000000
# 75%     13034.5000            2012-07-02 00:00:00      3.000000      1.000000
# max     17379.0000            2012-12-31 00:00:00      4.000000      1.000000
# std      5017.0295                            NaN      1.106918      0.500008
#
# ...

# %% [markdown]
# Berdasarkan rangkuman parameter statistik di atas, kita akan memperoleh informasi jumlah pelanggan sebanyak 17397. Data menunjukkan bahwa penyewaan sepeda berlangsung dalam rentang waktu 00:00 hingga 23:59, dengan rata-rata penyewaan terjadi sekitar pukul 11:54 dan memiliki standar deviasi sebesar 6,91.

# %%
# penyewaan berdasarkan jam
hour_df.groupby(by="hour").agg({
    "count_cr": ["sum"]
})
# Out:
#      count_cr
#           sum
# hour
# 0       39130
# 1       24164
# 2       16352
# 3        8174
# 4        4428
# 5       14261
# 6       55132
# 7      154171
# 8      261001
# 9      159438
# 10     126257
# 11     151320
# 12     184414
# 13     184919
# 14     175652
# 15     183149
# 16     227748
# 17     336860
# 18     309772
# 19     226789
# 20     164550
# 21     125445
# 22      95612
# 23      63941

# %% [markdown]
# Berdasarkan hasil diatas, pelanggan paling banyak menyewa sepada pada jam 17.00. Untuk penyewa sepeda paling sedikit terjadi pada jam 04.00

# %%
# penyewaan berdasarkan musim
hour_df.groupby(by="season").agg({
    "count_cr": ["sum"]
})
# Out:
#        count_cr
#             sum
# season
# 1        471348
# 2        918589
# 3       1061129
# 4        841613

# %% [markdown]
# Berdasarkan hasil pivot table diatas, jumlah penyewaan terbanyak terjadi pada musim gugur, dilanjutkan oleh musim panas, musim dingin, dan terendah terjadi pada musim semi

# %%
fig, axe = plt.subplots(figsize=(15,5))
correlation_matrix = hour_df.corr(numeric_only=True)
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))
sns.heatmap(correlation_matrix, annot=True, mask=mask, cmap="coolwarm", center=0, fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Berdasarkana matrix tersebut, kita mendapat beberapa informasi, yaitu
# 1. Korelasi positif kuat
# - temp dengan atemp
# - count_cr dengan registered
# - instant dengan year
# - season dengan month
# 2. Fitur yang memiliki korelasi kuat dengan total penyewaan sepeda, baik untuk penyewaan harian maupun pengguna terdaftar ("count_cr"), antara lain:
# - registered
# - casual

# %%
day_df.replace({
    "season": {1: "Spring", 2: "Summer", 3: "Fall", 4: "Winter"},
    "weather": {1: "Clear", 2: "Mist/Cloudy", 3: "Light Rain/Snow", 4: "Heavy Rain/Snow"},
    "year": {0: 2011, 1: 2012},
    "weekday": {0: "Sunday", 1: "Monday", 2: "Tuesday", 3: "Wednesday", 4: "Thursday", 5: "Friday", 6: "Saturday"}
    }, inplace=True)

# %%
hour_df.replace({
    "season": {1: "Spring", 2: "Summer", 3: "Fall", 4: "Winter"},
    "weather": {1: "Clear", 2: "Mist/Cloudy", 3: "Light Rain/Snow", 4: "Heavy Rain/Snow"},
    "year": {0: 2011, 1: 2012},
    "weekday": {0: "Sunday", 1: "Monday", 2: "Tuesday", 3: "Wednesday", 4: "Thursday", 5: "Friday", 6: "Saturday"}
    }, inplace=True)

# %%
# mengubah ke nilai asli
day_df['temp'] *= 41
day_df['atemp'] *= 50
day_df['humidity'] *= 100
day_df['wind_speed'] *= 67

hour_df['temp'] *= 41
hour_df['atemp'] *= 50
hour_df['humidity'] *= 100
hour_df['wind_speed'] *= 67

# %%
# penyewaan berdasarkan cuaca
hour_df.groupby(by="weather").agg({
    "count_cr": ["sum"]
})
# Out:
#                 count_cr
#                      sum
# weather
# Clear            2338173
# Heavy Rain/Snow      223
# Light Rain/Snow   158331
# Mist/Cloudy       795952

# %% [markdown]
# Berdasarkan hasil tersebut, terdapat perbedaan yang cukup signifikan pada penyewa sepeda di cuaca yang berbeda. Ini berarti bahwa cuaca mempengaruhi peminatan menyewa sepeda

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana tren pengguna baru dengan pengguna casual dalam beberapa tahun terakhir?

# %%
yearly_counts = day_df.groupby("year")[["casual", "registered"]].sum().reset_index()

bar_width = 0.3
index = np.arange(len(yearly_counts["year"]))
plt.figure(figsize=(8, 5))
p1 = plt.bar(index, yearly_counts["casual"], bar_width, label="Total Casual")
p2 = plt.bar(index + bar_width, yearly_counts["registered"], bar_width, label="Total Registered")
for bars in [p1, p2]:
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, height, f"{int(height)}", ha="center", va="bottom")

plt.xlabel(None)
plt.ylabel(None)
plt.title("Total Casual vs Registered Users by Year")
plt.xticks(index + bar_width / 2, yearly_counts["year"])
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - Jumlah pengguna baru lebih tinggi dibandingkan pengguna casual di kedua tahun
# - Tren tertinggi penyewaan sepeda terjadi pada pengguna baru di tahun 2012, yaitu 1.304.046 lebih banyak dari pengguna casual

# %% [markdown]
# ### Pertanyaan 2: Bagaimana pola penyewaan dari pagi hingga malam hari?

# %%
sum_order_items_df = hour_df.groupby(by=["hour","year"]).count_cr.sum().reset_index()

plt.figure(figsize=(10, 6))
sns.lineplot(data=sum_order_items_df, x="hour", y="count_cr", hue="year", marker="o", palette="bright")

plt.title("Tren penyewaan Sepeda Berdasarkan Jam dan tahun")
plt.legend(title="Tahun", loc="upper right")
plt.xticks(range(0, 24))
plt.tight_layout()
plt.grid(True)
plt.show()

# %% [markdown]
# **Insight:**
# - Jumlah penyewaan pada tahun 2012 meningkat signifikan dari tahun sebelumnya
# - Jam tengah malam hingga subuh (00.00 - 05.00) memiliki penyewaan paling rendah
# - Terjadi lonjakan penyewaan yang signifikan pada pagi (06:00 - 08:00) dan sore (16:00 - 17:00)
# - penyewaan sepada terbanyak terjadi pada jam 17.00 sedangkan terendah terjadi pada jam 04.00

# %% [markdown]
# ### Pertanyaan 3: Bagaimana pola penyewaan pada setiap musim?

# %%
season_counts = day_df.groupby(by=["season", "year"]).agg({
    "count_cr": "sum"
}).reset_index()

plt.figure(figsize=(8, 5))
sns.barplot(data=season_counts, x="season", y="count_cr", hue="year", palette="deep")
plt.xlabel(None)
plt.ylabel(None)
plt.title("Total penyewaan Sepeda Berdasarkan Musim")
plt.legend(title="Tahun", loc="upper right")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
# - Jumlah penyewaan pada tahun 2012 mengalami kenaikan yang signifikan dibanding tahun sebelumnya
# - Jumlah penyewaan yang tinggi terjadi di musim gugur dan panas, pada musim ini kondisi cuaca mendukung aktivitas luar ruangan dan bisa jadi banyak orang menggunakan sepeda untuk berangkat kerja atau bersenang-senang
# - Pada musim dingin, tidak lebih tinggi dari musim gugur dan panas
# - Jumlah penyewaan cukup rendah pada musim semi karena cuaca yang tidak menentu

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Jumlah pengguna baru yang menyewa sepeda lebih tinggi daripada pengguna casual pada tahun 2011 dan 2012. Perbedaan ini semakin signifikan pada tahun 2012 dengan lebih banyak pengguna baru sebanyak 1.304.046 daripada pengguna casual
# - Jumlah penyewaan sepeda mengalami peningkatan signifikan pada tahun selanjutnya (2012). Pola penggunaan menunjukkan bahwa penyewaan sepeda paling rendah terjadi pada rentang waktu tengah malam hingga subuh dengan titik terendah pada pukul 04.00. Selain itu, terjadi lonjakan pada pagi(06.00 - 08.00) dan sore hari(16.00 - 17.00) yang kemungkinan besar berkaitan dengan mobilitas masyarakat saat berangkat dan pulang kerja / sekolah. Puncak penyewaan terjadi pada pukul 17.00
# - Tren penyewaan pada musim gugur dan musim panas menjadi periode dengan jumlah penyewaan tertinggi, kemungkinan karena kondisi cuaca yang mendukung aktivitas luar ruangan dan meningkatnya penggunaan sepeda untuk transportasi. Pada musim dingin, jumlah penyewaan tidak setinggi musim gugur dan panas. Pada musim semu jumlah penyewaan rendah karena cuaca yang tidak menentu

# %%
day_df.to_csv("day_clean.csv", index=False)
hour_df.to_csv("hour_clean.csv", index=False)
